# %% [markdown]
# # Ignaz Semmelweis - The discovery on why washing hands can save lives

# %% [markdown]
# ## 0 - General
# Some information before we start working on this project
# * I will upload **one version without solutions** and **one with solutions** (or approaches)
#
# * My "solution" is one approach, if you have another one I am fine with that too
#
# * We will use **Python 3** during the lecture and exercises. If you feel better using R, go ahead! I used R during my time at the University of Münster, too.

# %% [markdown]
# ## 1 - Meet Ignaz Semmelweis

# %% [markdown]
# <img style="float: left; margin-right: 1em;" src="https://upload.wikimedia.org/wikipedia/commons/4/45/Semmelweis_Ign%C3%A1c-001.png"> This is **Ignaz Philipp Semmelweis** (1818-1865). He was a Hungarian doctor and scientist who **proposed the practice of washing hands** with chlorinated lime solutions in 1847 **while working in Vienna General Hospital's First Obstetrical Clinic**.
#
# <i>The Viennese hospital had **two maternity clinics**. The **First Clinic had an average maternal mortality rate of about 10%** due to puerperal fever. The **Second Clinic's rate** was considerably lower, averaging **less than 4%**. This fact was known outside the hospital. The two clinics admitted on alternate days, but **women begged to be admitted to the Second Clinic, due to the bad reputation of the First Clinic**. Semmelweis described desperate women begging on their knees not to be admitted to the First Clinic. Some **women** even **preferred to give birth in the streets**, pretending to have given sudden birth en route to the hospital (a practice known as street births), which meant they would still qualify for the child care benefits without having been admitted to the clinic. Semmelweis was **puzzled that puerperal fever was rare among women giving street births**. "To me, it appeared logical that patients who experienced street births would become ill at least as frequently as those who delivered in the clinic. [...] What protected those who delivered outside the clinic from these destructive unknown endemic influences?"</i>
#
# <sub> (Source: https://en.wikipedia.org/wiki/Ignaz_Semmelweis)</sub>

# %% [markdown]
# ## 2 - NPR radio report about Ignaz Semmelweis  📻👂🏼
#
# Head over to https://www.npr.org/sections/health-shots/2015/01/12/375663920/the-doctor-who-championed-hand-washing-and-saved-women-s-lives and listen to the radio report. $\rightarrow$ We will continue this project in 10 minutes :)

# %% [markdown]
# ## 3 - Our goal in this project
# In this project we are going to **apply the theory we learned during the lecture** to **reproduce Semmelweis' results**.
#
# Remember the OSEMN data science process?

# %% [markdown]
# <img src="data:image/png;base64,..." />

# %% [markdown]
# In this exercise we are going to focus on the first three steps for now:
# 1. We are obtaining the data -- We have to retrieve a copy of the dataset
# 2. We clean the data if there is anything wrong
# 3. We explore the data. This is also called **EDA** - Exploratory Data Analysis

# %% [markdown]
# ## 4 - The first step: Obtain data 📝 and some Data Scrubbing 🧼
# Back in the 1840s, when Semmelweis collected the data, there were significant differences between the mortality rate in the first clinic and the second clinic of the Vienna hospital. In 2021 the importance of hygiene is well known and the same observations would most likely not be possible.
#
# As a result, we cannot collect data ourselves, but instead we are going to use the data which was collected by Semmelweis himself.
#
# **Your task** Try to find the data which has been collected by Semmelweis! We are interested in the following data: Mortality rates for the First and Second Clinic at the Vienna General Hospital for the years 1841 to 1846
#
# *Hint*: I am not looking for an available data on kaggle, datacamp or github, but for the data which has been reported by Semmelweis himself!

# %% [markdown]
# ## 4.1 - Data Preparation 🛠 (and some Data Scrubbing 🧼)
# The data we found is unfortunately not machine readable yet since it's only available as a pdf file. As you probably know, one common format for data is the **comma-separated values** (CSV)-fileformat. This format is readable by multiple tools like Microsoft Excel, R or Python.
#
# If you obtain data yourself, e.g. using an online questionnaire, it is likely that you can export your data to CSV. Addtionally, many datasets you are going to find, are available in the CSV-fileformat.
#
# As a result, we want to convert our PDF to a CSV file.
#
# 1. Convert the data **manually**
#
# You could open Excel, numbers etc. and copy the data into a spreadsheet yourself. After you filled in the data, these tools can export your data to a CSV file.
# For small amounts of data (like in our case), this is a good choice. However, once the data gets bigger this is not feasible.
#
#
# 2. Convert the data **automatically** 🤖
#
# To convert the data automatically from PDF to CSV, there are numerous ways. One idea is to take a screenshot of the data table in the PDF and to import the screenshot into Excel. You can then export your data as CSV. The process is described <a href="https://support.microsoft.com/en-us/office/insert-data-from-picture-3c1bb58d-2c59-4bc0-b04a-a671a6868fd7">here</a>.
#
# We want to use an approach which is independent from the operating system and software. We use an online service to convert the table from the PDF to text:
#
# * We go to https://img2txt.com/
# * We upload an image of the table
# * The following data has been returned
#
#
# ```
# Births Deaths Rate Births Deaths Rate
# 1841 2813 177 6.2 2252 9) 4.04
# 1842 3037 279 9.1] 2414 113 4.06
# 1843 2828 195 6.8 2570 130 5.05
# 1844 2917 251 8.6 2739 100 3.06
# 1845 3201 260 8.1 3017 97 3.02
# 1846 3533 235 6.5 3398 86 2.05
# ```
#
# $\rightarrow$ Look at the data! What is wrong?
#
# The last problem is that the data is separated by spaces, but for the CSV fileformat a comma as separator is required. As a result, we replace every space with a comma and have the final dataset which we can save as 'semmelweis_dataset.csv'
#
# **Your task** Upload an image of the table yourself to https://img2txt.com, then fix the data in the dataset. Finally, replace all spaces with a comma in a text editor and save the file as 'semmelweis_dataset.csv'

# %% [markdown]
# ## 4.2 Upload the dataset to the server
# We use an online version of jupyter notebooks - that's the reason why you did not have to install Python. To use the dataset on the server, you need to upload it.
#
# **Your task** Follow the instructions shown by Hilko

# %% [markdown]
# # 5 Explore Data - Exploratory Data Analysis

# %%
print('Hello world :-)')

# %% [markdown]
# Python is, in contrast to R, not tailored to statistics or machine learning, but it is a general purpose programming language. As a result, some statistics tools for Python have to be installed first. In Python, we call these tools <b>packages</b>. Packages can be compared to Libraries in Java or packages in R.
#
# In this environment we already installed all the necessary packages for you. If you decide to setup <b>Python locally on your machine</b>, you have to install these packages first. You can read a complete tutorial on how to setup Python for Data Science <a href="https://drivendata.github.io/pydata-setup/">here</a>.
#
# Let's continue with the EDA by importing <b>pandas</b>. pandas is one of the de-facto standard packages for Python.

# %%
import pandas as pd

# %% [markdown]
# With this statement we told the Python interpreter that we want to use the pandas package and that we want to refer to pandas with "pd". Let's load our dataset to get started!

# %%
df = pd.read_csv('data/semmelweis_dataset.csv', sep=';', decimal=',')

# %% [markdown]
# Now we have loaded the dataset into a variable called **df** (which is short for DataFrame and often used in code snippets and examples). In my head a DataFrame is a table. Let's look into the data:

# %%
df.head()

# %% [markdown]
# You can see that we don't see all data if we call DataFrame.head(). The head-function is an overview and a good way to check if your data has been loaded correctly.
#
# **Your task**: Head over to the documentation and try to find out how to display 10 rows instead of 5. Hint: Look into the examples on the page :)

# %% [markdown]
# ## 5.1 Reproduce the observations by Dr. Semmelweis
#
# To reproduce the observations by Dr. Semmelweis we can plot the data he has been observing and have a look into it.

# %%
df.plot(x='Year',y='Rate')

# %% [markdown]
# ### What went wrong?
#
# 💡 The graph shows data that belongs to the first **and** second clinic. That's the reason why there are two data points for each year. To plot the data correctly we need to separate the data by their location.
#
# **Your task**: Read <a href="https://pandas.pydata.org/pandas-docs/stable/getting_started/intro_tutorials/03_subset_data.html">here</a> how to select specific rows from the dataset. Create two new DataFrames: One with the data for Clinic 1 (i.e. where column *Location* has the value *clinic_1*) and one for Clinic 2 (i.e.where column *Location* has the value *clinic_2*)

# %%
...

# %% [markdown]
# Now we can plot the data from the first clinic:

# %%
ax1 = df_first_clinic.plot(x='Year',y='Rate', label='First Clinic')
df_second_clinic.plot(ax=ax1, x='Year',y='Rate', label='Second Clinic')

# %% [markdown]
# In the lecture you learned about different summary statistics, e.g. mean or standard deviation.
# Pandas has an easy method to print the statistics.
#
# **Your task**: Google on how to print summary statistics of a DataFrame. Then print the summary statistics for both DataFrame. What's the average mortality rate of the First Clinic compared to the rate of the second clinic?
# What's the median mortality rate of both clinics?

# %%
...

# %%
...

# %% [markdown]
# Write a small summary on what you could find out until now and focus on the following points:
# 1. How did you get the data? Is it a lot of data? Can you trust the data?
# 2. How does the first clinic compare to the second clinic? Can you support Semmelweiser's observation that the mortality rate in the first clinic is a lot higher than in the second clinic?

# %% [markdown]
# Lastly, we want to have a look on how washing hands had an influence on the mortality rate. In the data directory is another dataset, called 'semmeleweiser_details.parquet'.
#
# **Your task**: Find out...
#
# (1) What Parquet is and
#
# (2) How to read in the data into a DataFrame using pandas

# %% [markdown]
# 💡 **Parquet** is a file format which was developed especially for distributed computing. Compared to CSV it offers advantages such as preservation of data types, small data files and compression.

# %%
...

# %%
# First we add a Rate column
df_details['Rate'] = (df_details['Deaths'] / df_details['Births'])*100

# %%
# Add a column to if handwashing has been applied
df_details['Handwashing'] = df_details['Date'] > pd.to_datetime('1847-05-01')

# %%
df_before_handwashing = df_details[~df_details['Handwashing']]
df_after_handwashing = df_details[df_details['Handwashing']]

# %%
df_before_handwashing.head(30)

# %%
ax1 = df_before_handwashing.plot(x='Date', y='Rate', c='b', label='Before Handwashing')
df_after_handwashing.plot(x='Date', y='Rate', c='r', ax=ax1, label='After Handwashing')
ax1.set_ylabel('Mortality Rate')

# %% [markdown]
# ## 6. Lessons learned 📚
# What should you learn during this session?
#
# Methodology:
# * **Collecting and Preparing** Data
# * **Pandas** DataFrame
#     * Adding Columns
#     * **Describing** DataFrames ("Summary")
#     * **Plotting** Data
#     * **Selecting** Data
# * CSV Files, Parquet Files
#
# $\rightarrow$ relevant for your exam and data science project!
#
# Scientifically:
# * Handwashing helps 🧼😀

# %% [markdown]
# ## Further exercises
# * There is even more data available which was not included in this exercise because I did not found the primary source for the data translated into English. However, you can get the data <a href="https://en.wikipedia.org/wiki/Historical_mortality_rates_of_puerperal_fever#Yearly_mortality_rates_for_birthgiving_women_1833%E2%80%9358_for_first_and_second_clinics">here</a>

# %% [markdown]
# ## Sources
# The following sources were used for creating this jupyter notebook
# * Idea: https://www.datacamp.com/projects/20
# * Information about Semmelweis: https://en.wikipedia.org/wiki/Ignaz_Semmelweis and https://de.wikipedia.org/wiki/Ignaz_Semmelweis
# * Original Dataset: https://www.deutschestextarchiv.de/book/show/semmelweis_kindbettfieber_1861
#
# Further sources and information
# * NPR https://www.npr.org/sections/health-shots/2015/01/12/375663920/the-doctor-who-championed-hand-washing-and-saved-women-s-lives
# * https://www.datasciencecentral.com/profiles/blogs/how-a-good-data-visualization-could-save-lives
# * https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3807776/
#
# Dr. Semmelweis is not undisputed. For further information read here: Shattering the Myth of Semmelweis (https://www.jstor.org/stable/10.1086/673935)
